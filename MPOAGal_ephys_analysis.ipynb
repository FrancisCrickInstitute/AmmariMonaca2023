# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
sns.set_context('talk')
import scipy
from scipy.stats import sem
from pylab import *
from pandas.api.types import CategoricalDtype
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import data

# %%
df = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/Figure_2/ephys_analysis/mpoa_ephys.csv')

# %% [markdown]
# # Define groups

# %%
subsets = [df[(df['state'] == 'virgin')], df[(df['state'] == 'D10')], df[(df['state'] == 'D18')], df[(df['state'] == 'D18-PR')],
           df[(df['state'] == 'D18-Esr')], df[(df['state'] == 'D18-ctrl')], df[(df['state'] == 'D50')], df[(df['state'] == 'D18-GIRK-Tertiapin Q')],
           df[(df['state'] == 'D22')], df[(df['state'] == 'D22-PR')], df[(df['state'] == 'Virgin-Gal-')], df[(df['state'] == 'D18-Gal-')]]

vir, d10, d18, d18_pr, d18_esr, d18_ctrl, d50, girk, d22, d22_pr, vir_galno, d18_galno = subsets

# %% [markdown]
# # Plotting

# %%
# define colors
colors2 = ['#0000ff', '#d7301f']
colors_ctrl = ['#d7301f', '#d7301f']
colors2_inv = ['#d7301f','#0000ff']
colors_pr = ['#d7301f', '#808080']
colors = ['#0000ff', '#FAA41F', '#d7301f']
colors_perc = ['#0000ff', '#d7301f', '#d7301f', '#d7301f']
colors4 = ['#0000ff', '#d7301f', '#d7301f', '#d7301f']
colors5 = ['#0000ff', '#d7301f', '#d7301f', '#d7301f', '#d7301f']
colors7 = ['#0000ff', '#d7301f', '#808080', '#808080']
colors_corr2 = ['#0000ff', '#d7301f', '#0000ff', '#d7301f']
colors_girk = ['#0000ff', '#FAA41F', '#d7301f', '#d7301f', '#d7301f', '#d7301f','#d7301f']

# %% [markdown]
# ## Membrane capacitance

# %%
len(df)
# Out:
# 270

# %%
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='Cm', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='Cm', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Cm (pF)')

ax.set_xticklabels( ('Vir', 'D10','D18'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
plt.ylim(0, 200)
sns.despine(bottom=True, trim=False)
ax.tick_params(bottom=False)

for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   import sys

# %% [markdown]
# ## Membrane voltage

# %%
#### main figure

sns.set(rc={"figure.figsize": (4.5, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")
ax = sns.boxplot(x='state', y='vm', data = df, order = ['virgin', 'D18', 'D18-GIRK-Tertiapin Q', 'D18-Esr', 'D18-PR'], saturation=8, palette=colors5, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='vm', data = df, order = ['virgin', 'D18', 'D18-GIRK-Tertiapin Q', 'D18-Esr', 'D18-PR'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors5, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Vm (mV)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', 'Tert-Q', '$\mathregular{Esr1^{KO}}$', '$\mathregular{PR^{KO}}$'), rotation=45)
plt.ylim(-65, 0)
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
#### Vir, D10, D18
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")
ax = sns.boxplot(x='state', y='vm', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='vm', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Vm (mV)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D10', 'D18'), rotation=45)
plt.ylim(-65, 0)
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   import sys

# %%
# Vir, D18, D22, D50
sns.set(rc={"figure.figsize": (3.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='vm', data = df, order = ['virgin', 'D18', 'D22', 'D50'], saturation=8, palette=colors7, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='vm', data = df, order = ['virgin', 'D18', 'D22', 'D50'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors7, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Vm (mV)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', 'D22', 'D50'), rotation=45)
plt.ylim(-65, 0)
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# D18 wild-type and AAV ctrl 
sns.set(rc={"figure.figsize": (1.7, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='vm', data = df, order = ['D18', 'D18-ctrl'], saturation=8, palette=colors_ctrl, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='vm', data = df, order = ['D18', 'D18-ctrl'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors_ctrl, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Vm (mV)', labelpad=5)
ax.set_xticklabels( ('wt', 'ctrl'), rotation=45)
plt.ylim(-65, 0)
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Gal-negative neurons
sns.set(rc={"figure.figsize": (1.7, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='vm', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='vm', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Vm (mV)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(-65, 0)
ax.yaxis.set_major_locator(plt.MaxNLocator(5))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %% [markdown]
# ## Input resistance

# %%
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='ir', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='ir', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Input resistance\n(MΩ)', labelpad=5)

ax.set_xticklabels( ('Vir', 'D10','D18'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(3))
plt.ylim(0, 1800)
sns.despine(bottom=True, trim=False)
ax.tick_params(bottom=False)

for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   import sys

# %% [markdown]
# ## Firing frequency

# %%
# Vir, D10, D18
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='ff', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='ff', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Firing freq. (Hz)', labelpad=15)
ax.set_xticklabels( ('Vir', 'D10','D18'), rotation=45)
plt.ylim(top=10)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, offset=1, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Vir, D18, D22, D50
sns.set(rc={"figure.figsize": (3.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='ff', data = df, order = ['virgin', 'D18', 'D22', 'D50'], saturation=8, palette=colors7, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='ff', data = df, order = ['virgin', 'D18', 'D22', 'D50'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors7, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Firing freq. (Hz)', labelpad=15)
ax.set_xticklabels( ('Vir', 'D18','D22', 'D50'), rotation=45)
plt.ylim(top=10)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, offset=1, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Gal-negative neurons
sns.set(rc={"figure.figsize": (1.7, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='ff', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='ff', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Firing freq. (Hz)', labelpad=10)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=6)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %% [markdown]
# #### Cumulative histograms

# %%
# Vir, D18
df2 = pd.concat([vir, d18], ignore_index=True)

sns.set(rc={"figure.figsize": (2.5, 2.0)})
sns.set(font_scale=2) 
sns.set_style("ticks")
cum = sns.ecdfplot(data=df2, x="ff", hue="state", palette=colors2, linewidth=2.5, legend=False, stat='proportion')
cum.set_xlabel('Baseline\nfreq. (Hz)',labelpad=5)
cum.set_ylabel('Fraction',labelpad=10)
cum.xaxis.set_major_locator(plt.MaxNLocator(3))
plt.xlim(right=10)
sns.despine(trim=True)

# %%
# Gal-negative Vir, D18

df_no = pd.concat([vir_galno, d18_galno], ignore_index=True)

sns.set(rc={"figure.figsize": (2.5, 2.0)})
sns.set(font_scale=2) 
sns.set_style("ticks")
cum = sns.ecdfplot(data=df_no, x="ff", hue="state", palette=colors2, linewidth=2.5, legend=False, stat='proportion')
cum.set_xlabel('Baseline\nfreq. (Hz)',labelpad=5)
cum.set_ylabel('Fraction',labelpad=10)
cum.xaxis.set_major_locator(plt.MaxNLocator(3))
plt.xlim(right=3) #was 10
sns.despine(trim=True)

# %% [markdown]
# ## AP halfwidth

# %%
sns.set(rc={"figure.figsize": (3.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='hw', data = df, order = ['virgin', 'D18', 'D22', 'D50'], saturation=8, palette=colors7, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='hw', data = df, order = ['virgin', 'D18', 'D22', 'D50'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors7, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('AP halfwidth (mV)', labelpad=5)

ax.set_xticklabels( ('Vir', 'D18','D22', 'D50'), rotation=45)
boxprops = dict(linestyle='-', linewidth=1, color='#FFCC00')

plt.ylim(-2, 24)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   import sys

# %%
# Gal-negative Vir, D18
sns.set(rc={"figure.figsize": (1.7, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='hw', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='hw', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('AP halfwidth (mV)', labelpad=10)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(-2, 12)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %% [markdown]
# ## Rheobase at -60mV

# %%
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='rheo', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='rheo', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('Rheobase (pA)')

ax.set_xticklabels( ('Vir', 'D10','D18'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(3))
plt.ylim(0, 60)
sns.despine(bottom=True, trim=False)
ax.tick_params(bottom=False)

for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   import sys

# %% [markdown]
# ## sPSC frequency

# %%
# Vir, D18, Esr1-KO, PR-KO
sns.set(rc={"figure.figsize": (3.4, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='s_freq', data = df, order = ['virgin', 'D18', 'D18-Esr', 'D18-PR'], saturation=8, palette=colors4, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='s_freq', data = df, order = ['virgin', 'D18', 'D18-Esr', 'D18-PR'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors4, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('sPSC freq. (Hz)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', '$\mathregular{Esr1^{KO}}$', '$\mathregular{PR^{KO}}$'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Vir, D18, D22, D50
sns.set(rc={"figure.figsize": (3.6, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='s_freq', data = df, order = ['virgin', 'D18', 'D22', 'D50'], saturation=8, palette=colors7, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='s_freq', data = df, order = ['virgin', 'D18', 'D22', 'D50'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors7, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('sPSC freq. (Hz)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', 'D22', 'D50'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# D18 wild-type and AAV ctrl 
sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='s_freq', data = df, order = ['D18', 'D18-ctrl'], saturation=8, palette=colors_ctrl, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='s_freq', data = df, order = ['D18', 'D18-ctrl'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors_ctrl, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('sPSC freq. (Hz)', labelpad=10)
ax.set_xticklabels( ('wt', 'ctrl'), rotation=45)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Vir, D10, D18
sns.set(rc={"figure.figsize": (2.6, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='s_freq', data = df, order = ['virgin', 'D10', 'D18'], saturation=8, palette=colors, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='s_freq', data = df, order = ['virgin', 'D10', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('sPSC freq. (Hz)', labelpad=5)
ax.set_xticklabels( ('Vir', 'D10', 'D18'), rotation=45)
plt.ylim(0, 10)
ax.yaxis.set_major_locator(plt.MaxNLocator(3))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# Gal-negative Vir, D18
sns.set(rc={"figure.figsize": (1.7, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='s_freq', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='s_freq', data = df, order = ['Virgin-Gal-', 'D18-Gal-'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=0.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('sPSC freq. (Hz)', labelpad=10)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(-2, 10)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %% [markdown]
# ## sPSC amplitude

# %%
# Vir, D18
sns.set(rc={"figure.figsize": (4, 2.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

hist = sns.histplot(df, x="s_amp", hue="state", element="step", stat="proportion", common_norm=False, multiple="dodge", 
                    legend=False, kde=True, palette=colors2_inv, hue_order = ['D18', 'virgin'], alpha=.35, fill=False)
plt.ylim(0,0.3)
hist.yaxis.set_major_locator(plt.MaxNLocator(2)) 
hist.xaxis.set_major_locator(plt.MaxNLocator(3)) 
hist.set_xlabel('Peak amplitude\nsPSCs (pA)',labelpad=5)
hist.set_ylabel('Proportion',labelpad=10)
sns.despine(bottom=True, trim=False)

# %% [markdown]
# ## sPSC rise time

# %%
# Vir, D18
sns.set(rc={"figure.figsize": (4, 2.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

hist = sns.histplot(df, x="s_rise", hue="state", element="step", stat="proportion", common_norm=False, multiple="dodge", 
                    legend=False, kde=True, palette=colors2_inv, hue_order = ['D18', 'virgin'], alpha=.35, fill=False)
plt.ylim(0,0.4)
hist.yaxis.set_major_locator(plt.MaxNLocator(2)) 
hist.xaxis.set_major_locator(plt.MaxNLocator(3)) 
hist.set_xlabel('Rise time sPSCs\n(ms)',labelpad=5)
hist.set_ylabel('Proportion',labelpad=10)
sns.despine(bottom=True, trim=False)

# %%
# Gal-negative Vir, D18
sns.set(rc={"figure.figsize": (4, 2.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

hist = sns.histplot(df, x="s_rise", hue="state", element="step", stat="proportion", common_norm=False, multiple="dodge", 
                    legend=False, kde=True, palette=colors2_inv, hue_order = ['Virgin-Gal-', 'D18-Gal-'], alpha=.35, fill=False)
plt.ylim(0,0.6)
hist.yaxis.set_major_locator(plt.MaxNLocator(2)) 
hist.xaxis.set_major_locator(plt.MaxNLocator(3)) 
hist.set_xlabel('Rise time sPSCs\n(ms)',labelpad=5)
hist.set_ylabel('Proportion',labelpad=10)
sns.despine(bottom=True, trim=False)

# %% [markdown]
# ## sPSC decay time

# %%
# Vir, D18
sns.set(rc={"figure.figsize": (4, 2.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

hist = sns.histplot(df, x="s_decay", hue="state", element="step", stat="proportion", common_norm=False, multiple="dodge", 
                    legend=False, kde=True, palette=colors2_inv, hue_order = ['D18', 'virgin'], alpha=.35, fill=False)
plt.ylim(0,0.4)
hist.yaxis.set_major_locator(plt.MaxNLocator(2)) 
hist.xaxis.set_major_locator(plt.MaxNLocator(3)) 
hist.set_xlabel('Time const. of decay\nsPSCs (ms)',labelpad=5)
hist.set_ylabel('Proportion',labelpad=10)
sns.despine(bottom=True, trim=False)

# %%
# Gal-negative Vir, D18
sns.set(rc={"figure.figsize": (4, 2.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

hist = sns.histplot(df, x="s_decay", hue="state", element="step", stat="proportion", common_norm=False, multiple="dodge", 
                    legend=False, kde=True, palette=colors2_inv, hue_order = ['Virgin-Gal-', 'D18-Gal-'], alpha=.35, fill=False)
plt.ylim(0,0.4)
hist.yaxis.set_major_locator(plt.MaxNLocator(2)) 
hist.xaxis.set_major_locator(plt.MaxNLocator(3)) 
hist.set_xlabel('Time const. of decay\nsPSCs (ms)',labelpad=5)
hist.set_ylabel('Proportion',labelpad=10)
sns.despine(bottom=True, trim=False)

# %% [markdown]
# ## EPSC and IPSC frequency

# %%
psc = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/Figure_2/ephys_analysis/psc.csv')

# %%
psc
# Out:
#        experiment  ID mouse   frequency_Glu_Hz  frequency_GABA_Hz   state
# 0   S1C1 01122020  JKAM16.1d          2.531429           0.831568  virgin
# 1   S1C2 01122020        NaN          3.299296           3.375536  virgin
# 2   S1C3 01122020        NaN          3.551601           5.083947  virgin
# 3   S1C4 01122020        NaN          0.102941           1.569740  virgin
# 4   S1C5 01122020        NaN          0.492147           4.081232  virgin
# ..            ...        ...               ...                ...     ...
# 57  S1C3 09042022        NaN          2.730198           1.643192     D18
# 58  S1C4 09042022        NaN          1.565104           0.665865     D18
# 59  S2c1 09042022        NaN          2.106312           1.521445     D18
# 60  S2c2 09042022        NaN          1.153333           3.023649     D18
# 61  S2c3 09042022        NaN          1.340000           1.435000     D18
#
# [62 rows x 5 columns]

# %%
# EPSCs
sns.set(rc={"figure.figsize": (1.5, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='frequency_Glu_Hz', data = psc, order = ['virgin', 'D18'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='frequency_Glu_Hz', data = psc, order = ['virgin', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('EPSC freq. (Hz)', labelpad=10)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=4.5)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
# IPSCs
sns.set(rc={"figure.figsize": (1.5, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.boxplot(x='state', y='frequency_GABA_Hz', data = psc, order = ['virgin', 'D18'], saturation=8, palette=colors2, linewidth=1.7, showfliers = False)
ax = sns.stripplot(x='state', y='frequency_GABA_Hz', data = psc, order = ['virgin', 'D18'], jitter=True, dodge=False, 
              marker='o', size=7, linewidth=1, edgecolor='gray', palette=colors2, alpha=.5, zorder=0)
ax.set_xlabel('')
ax.set_ylabel('IPSC freq. (Hz)', labelpad=10)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=8)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .5))
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %% [markdown]
# ## % of silent neurons

# %%
sil = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/Figure_2/ephys_analysis/mpoa_activity_types.csv')
sil['total'] = sil.active + sil.silent
sil['pcy'] = sil.silent / sil.total * 100

# %%
sil1 = sil.drop(labels=[3,7,9,10], axis=0).reset_index(drop=True)
new_order = [0,1,2,6,3,4,5]
sil1 = sil1.reindex(new_order).reset_index(drop=True)
# add minimal value to GIRK so we can see column
sil1.at[3, 'pcy'] = 2

# %%
# all groups
sns.set(rc={"figure.figsize": (6, 3)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = sil1, order = ['virgin', 'PD10', 'PD18', 'GIRK','Esr1', 'PR', 'ctrl'],
                 palette=colors_girk, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% silent neurons', labelpad=5)
ax.set_xticklabels( ('Vir', 'D10', 'D18', 'Tert-Q', '$\mathregular{Esr1^{KO}}$', '$\mathregular{PR^{KO}}$', 'ctrl'), rotation=45)
plt.ylim(top=40)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
sil2 = sil.drop(labels=[1,4,5,6,8,9,10], axis=0).reset_index(drop=True)
new_order2 = [0,1,3,2]
sil2 = sil2.reindex(new_order2).reset_index(drop=True)

# %%
# Vir, D18, D22, D50
sns.set(rc={"figure.figsize": (3.5, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = sil2, order = ['virgin', 'PD18', 'PD22', 'PD50'],
                 palette=colors7, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% silent neurons', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', 'D22', 'D50'), rotation=45)
plt.ylim(top=40)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
sil3 = sil.drop(labels=[0,1,3,4,5,7,8,9,10], axis=0).reset_index(drop=True)

# %%
# D18 wild-type and AAV ctrl 
sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = sil3, order = ['PD18', 'ctrl'], palette=colors_ctrl, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% silent neurons', labelpad=5)
ax.set_xticklabels( ('wt', 'ctrl'), rotation=45)
plt.ylim(top=40)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
sil4 = sil.drop(labels=[0,1,2,3,4,5,6,7,8], axis=0).reset_index(drop=True)

# %%
# Gal-negative Vir and D18
sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = sil4, order = ['Vir-Gal-', 'D18-Gal-'], palette=colors2, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% silent neurons', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %% [markdown]
# ## Depolarization block

# %%
db = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/Figure_2/ephys_analysis/depol_block.csv')
db['total'] = db.yes + db.no
db['pcy'] = db.yes / db.total * 100

# %%
# Vir, D18
db1 = db.drop(labels=[1,3,4,5,6,7,8,9,10], axis=0)

sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = db1, order = ['Vir', 'D18'], 
                 palette=colors2, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% neurons with\ndepol. block', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
# Vir, D18, Esr1-KO, PR-KO
db2 = db.drop(labels=[1,3,6,7,8,9,10], axis=0).reset_index(drop=True)
new_order3 = [0,1,3,2]
db2 = db2.reindex(new_order3).reset_index(drop=True)

sns.set(rc={"figure.figsize": (3.2, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = db2, order = ['Vir', 'D18', 'D18-Esr', 'D18-Pr'], 
                 palette=colors_perc, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% neurons with\ndepol. block', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', '$\mathregular{Esr1^{KO}}$', '$\mathregular{PR^{KO}}$'), rotation=45)
# ax.set_xticklabels( ('Vir', '', 'D18', ''))
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
# D18 wild-type and AAV ctrl
db3 = db.drop(labels=[0,1,3,4,5,7,8,9,10], axis=0).reset_index(drop=True)

sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = db3, order = ['D18', 'D18-ctrl'], 
                 palette=colors_ctrl, linewidth=1.7, alpha=0.8)
ax.set_xlabel('')
ax.set_ylabel('% neurons with\ndepol. block', labelpad=5)
ax.set_xticklabels( ('wt', 'ctrl'), rotation=45)
# ax.set_xticklabels( ('Vir', '', 'D18', ''))
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
# Vir, D18, D22, D50
db4 = db.drop(labels=[1,4,5,6,7,9,10], axis=0).reset_index(drop=True)
db4 = db4.reindex(new_order3).reset_index(drop=True)

sns.set(rc={"figure.figsize": (3.5, 4)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = db4, order = ['Vir', 'D18', 'D22', 'D50'], 
                 palette=colors7, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% neurons with\ndepol. block', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18', 'D22', 'D50'), rotation=45)
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4)) # set a defined number of axis ticks
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %%
# Gal-negative Vir, D18
db5 = db.drop(labels=[0,1,2,3,4,5,6,7,8], axis=0).reset_index(drop=True)

sns.set(rc={"figure.figsize": (1.7, 3.5)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

ax = sns.barplot(x='Stage', y='pcy', data = db5, order = ['Vir-Gal-', 'D18-Gal-'], palette=colors2, linewidth=1.7, alpha=0.8)

ax.set_xlabel('')
ax.set_ylabel('% neurons with\ndepol. block', labelpad=5)
ax.set_xticklabels( ('Vir', 'D18'), rotation=45)
plt.ylim(top=100)
ax.yaxis.set_major_locator(plt.MaxNLocator(4))
sns.despine(bottom=True, trim=True)
ax.tick_params(bottom=False)

# %% [markdown]
# ## F-I curves

# %%
# Gal neurons
ramp = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/figure_S6/ramp_gal.csv')

sns.set(rc={"figure.figsize": (3.5, 3)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

x = sns.lineplot(y = 'spikes',x = 'ramp_current', data = ramp, hue='state', err_style='bars', ci=58, marker='o', lw=3, palette=colors2, alpha=0.5)

x.set_ylabel('Evoked action\npotentials', labelpad=5)
x.set_xlabel('Current (pA)', labelpad=5)
x.xaxis.set_major_locator(plt.MaxNLocator(4))
x.yaxis.set_major_locator(plt.MaxNLocator(5))
x.legend_.remove()
sns.despine()
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 58)` for the same effect.

# %%
# Gal-negative neurons
ramp_neg = pd.read_csv('/Volumes/lab-kohlj-1/home/shared/projects/pregnancyMPOA/Raw_data/figure_S6/ramp_gal_neg.csv')

sns.set(rc={"figure.figsize": (3.5, 3)})
sns.set(font_scale=2.5) 
sns.set_style("ticks")

x = sns.lineplot(y = 'spikes',x = 'ramp_current', data = ramp_neg, hue='state', err_style='bars', ci=58, marker='o', lw=3, palette=colors2, alpha=0.5)

x.set_ylabel('Evoked action\npotentials', labelpad=5)
x.set_xlabel('Current (pA)', labelpad=5)
x.xaxis.set_major_locator(plt.MaxNLocator(4))
x.yaxis.set_major_locator(plt.MaxNLocator(5))
x.legend_.remove()
sns.despine()
# Out:
# /Users/kohlj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 58)` for the same effect.
